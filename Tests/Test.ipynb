# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import os
import sys
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist

# %%
import metric

# %%
from sklearn.datasets import make_blobs
data = make_blobs(n_samples=200, n_features=2, 
                           centers=4, cluster_std=1.8,random_state=101)
plt.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

plt.show()

# %%
df = pd.DataFrame(data[0])

# %%
df['labels'] = data[1]

# %%
def generateID(df):
    listID = np.random.randint(0,len(df),len(df))
    df['ID'] = listID

# %%
generateID(df)

# %%
df.head()
# Out:
#           0          1  labels   ID
# 0 -6.428841  10.141117       3  152
# 1  5.868679   5.201104       2   41
# 2 -0.376109   3.264279       0   64
# 3  2.166792   9.563005       2   35
# 4  5.095086   7.207527       2   80

# %%
from sklearn.metrics.pairwise import euclidean_distances
metric.cluster_evaluation(data, data[1], euclidean_distances(data[0]), max_number_of_clusters = 5, y=data[1])
# Out:
# Result of silhouette: 0.5277296453101425
# Result of dunn index: 1.4016762687245226
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-1e6f94c3d273> in <module>()
#       1 from sklearn.metrics.pairwise import euclidean_distances
# ----> 2 metric.cluster_evaluation(data, data[1], euclidean_distances(data[0]), max_number_of_clusters = 5, y=data[1])
#
# ~\Documents\Git\Clusters-Metrics-Library\Tests\metric.py in cluster_evaluation(X, labels, distances, max_number_of_clusters, step, fig_size, cluster, y)
#     427     print("Result of dunn index: " + str(dunn(labels,distances)),"\n")
#     428     if max_number_of_clusters != None:
# --> 429         elbow(X,max_number_of_clusters,step)
#     430     silhouette_plot(distances,labels,metric= 'precomputed',fig_size = fig_size,cluster = cluster,y=y)
#
# ...

# %%
from sklearn.metrics.pairwise import euclidean_distances
metric.cluster_evaluation(data, data[1], euclidean_distances(data[0]), max_number_of_clusters = 5, y=df['ID'], cluster=1)
# Out:
# Result of silhouette: 0.5277296453101425
# Result of dunn index: 1.4016762687245226
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-b09513f066f8> in <module>()
#       1 from sklearn.metrics.pairwise import euclidean_distances
# ----> 2 metric.cluster_evaluation(data, data[1], euclidean_distances(data[0]), max_number_of_clusters = 5, y=df['ID'], cluster=1)
#
# ~\Documents\Git\Clusters-Metrics-Library\Tests\metric.py in cluster_evaluation(X, labels, distances, max_number_of_clusters, step, fig_size, cluster, y)
#     427     print("Result of dunn index: " + str(dunn(labels,distances)),"\n")
#     428     if max_number_of_clusters != None:
# --> 429         elbow(X,max_number_of_clusters,step)
#     430     silhouette_plot(distances,labels,metric= 'precomputed',fig_size = fig_size,cluster = cluster,y=y)
#
# ...

# %%
from sklearn.metrics.pairwise import euclidean_distances
metric.cluster_evaluation(data, data[1], euclidean_distances(data[0]), max_number_of_clusters = 5, y=df['ID'], cluster=2)
# Out:
# Result of silhouette: 0.5277296453101425
# Result of dunn index: 1.4016762687245226
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-ed5856cb6676> in <module>()
#       1 from sklearn.metrics.pairwise import euclidean_distances
# ----> 2 metric.cluster_evaluation(data, data[1], euclidean_distances(data[0]), max_number_of_clusters = 5, y=df['ID'], cluster=2)
#
# ~\Documents\Git\Clusters-Metrics-Library\Tests\metric.py in cluster_evaluation(X, labels, distances, max_number_of_clusters, step, fig_size, cluster, y)
#     427     print("Result of dunn index: " + str(dunn(labels,distances)),"\n")
#     428     if max_number_of_clusters != None:
# --> 429         elbow(X,max_number_of_clusters,step)
#     430     silhouette_plot(distances,labels,metric= 'precomputed',fig_size = fig_size,cluster = cluster,y=y)
#
# ...

# %%
metric.silhouette_plot(data[0],data[1],cluster=3)

# %%
metric.silhouette_plot(data[0],data[1],cluster=3,ID = df['ID'])
